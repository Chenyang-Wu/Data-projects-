# %% [markdown]
# Implement the a priori algorithm. Apply to datasets indicated in code below.
# You may work togehter, but you should make your own code. Share ideas about data structures and flow.
#
# **A priori algorthm**
#
# ```
# F_k: frequent k-itemsets
#
# L_k: candidate k-itemsets
#
# Algorithm
# * Let k=1
# * Generate F_1 = {frequent 1-itemsets}
# * Repeat until F_k is empty
#  * Candidate Generation: Generate L_(k+1) from F_k
#  * Candidate Pruning: eliminate candidate itemsets in L_k+1 containing subsets of length k that are infrequent
#  * Support Counting: Count the support of each candidate in L_(k+1) by scanning the DB (or use a more efficient hash method)
#  * Candidate Elimination: Eliminate candidates in L_(k+1) that are infrequent, leaving only those that are frequent => F_(k+1)
# ```

# %%
from google.colab import drive
drive.mount('/content/drive')
#!pip install mlxtend --upgrade
# Out:
# Mounted at /content/drive

# %%
#Functions and imports
#I had functions for candidate generation, candidate pruning, support count, and candidate elimination.
import pandas as pd
# from mlxtend.preprocessing import TransactionEncoder
# from mlxtend.frequent_patterns import apriori, fpmax, fpgrowth
import numpy as np
import math
from itertools import combinations

def create_1item_candidate(trans):
  c1 = []
  for i in trans:
    for item in trans[i]:
      item = frozenset([item])
      if item not in c1:
        c1.append(item)


  return c1
    
def find_freq_item(trans, ck, min_sup):
  item_track = {}
  for i in trans:
    for item in ck: 
      if item.issubset(trans[i]):
        if item not in item_track:
          item_track[item] = 1
        else:
          item_track[item] += 1
  N_row = i
  freq_item = []
  item_sup = {}

  for item in item_track:
    supp = item_track[item] / N_row
    if supp >= min_sup:
      freq_item.append(item)

    item_sup[item] = supp

  return freq_item, item_sup


def candidate_k(freq_item, k):
  ck = []

  if k == 0:
    for f1, f2 in combinations(freq_item, 2):
      item = f1 | f2
      ck.append(item)
  else:
    for f1, f2 in combinations(freq_item, 2):
      intsec = f1 & f2
      if len(intsec) == k:
        item = f1 | f2
        if item not in ck: 
          ck.append(item)
  
  return ck

# %%
#Main program. Some things below you may or may not want.


if __name__ == "__main__":

  #Transaction file name
  #trans_file_name = '/content/drive/MyDrive/CS Classes/CSC_373_Data_Mining/CSC_373_Student_Files/Data/GroceryStoreStacked.csv'
  #trans_file_name = '/content/drive/MyDrive/CS Classes/CSC_373_Data_Mining/CSC_373_Student_Files/Data/GroceryStoreStacked_sub.csv'
  #trans_file_name = '/content/drive/MyDrive/CS Classes/CSC_373_Data_Mining/CSC_373_Student_Files/Data/Table_5_1.txt'
  trans_file_name = '/content/drive/Shareddrives/CSC373_DMP_Wu_Chenyang/DMP_Association//Data/Copy of Assoc_Analysis_Vidhya.dat'
  print("Transaction file:", trans_file_name)
  #Set min_sup
  MIN_SUP = 0.1

  print("\nmin_sup",MIN_SUP)
  data_matrix = []
  trans = {}
  #data_matrix = pd.read_csv(trans_file_name)
  



  with open(trans_file_name,'r') as data_file_ptr:
    count = 0
    for dat_item in data_file_ptr:
      count +=1
      dat_item = dat_item.strip('\n')
      dat_item_list = dat_item.split(",")
      dat_item_list.pop(0)

      trans[count] = list(set(dat_item_list))
    #print(trans)
    c1 = create_1item_candidate(trans)
    freq_item, item_sup_all = find_freq_item(trans,c1,MIN_SUP)
    freq_items = [freq_item]
    cks = [c1]

    k = 0 
    while len(cks[k]) > 0 :
      freq_item = freq_items[k]
      ck = candidate_k(freq_item, k)
      freq_item, item_sup = find_freq_item(trans, ck, MIN_SUP)
      freq_items.append(freq_item)
      cks.append(ck)
      item_sup_all.update(item_sup)
      k += 1

    #print(freq_items)
    #print(cks)
    
    print("\n Number of transactions:", len(trans))
    print(item_sup_all)

    i = 1;
    for lists in cks:
      
      print("\n Candidate",i,"-itemset has ", len(lists), "items \n" )
      for supps in lists:
        print(" ", supps,": ",round(item_sup_all[supps],2),"  ", end = '')


      j = 0
      for supps in lists:
        if item_sup_all[supps] > MIN_SUP:
          j +=1
      

      for supps in lists:
        if item_sup_all[supps] > MIN_SUP:
          print(" ", supps,": ",round(item_sup_all[supps],2),"  ", end = '')
      

      print("\n \n Eliminated Candidate",i,"-itemset has ", len(freq_items[i-1]), "items \n" )

      for freq_supps in freq_items[i-1]:
        print(" ", freq_supps,": ",round(item_sup_all[freq_supps],2),"  ", end = '')
      print("")
      i +=1 
      
    

  



#print(data_matrix)
#print(frequent_itemsets)
  #My overall code flow followed the algorithm. I did build in some efficiencies
  #  for candidate generation.
# Out:
# Transaction file: /content/drive/Shareddrives/CSC373_DMP_Wu_Chenyang/DMP_Association//Data/Copy of Assoc_Analysis_Vidhya.dat
#
# min_sup 0.1
#
#  Number of transactions: 315
# {frozenset({'Diaper'}): 0.40634920634920635, frozenset({'Cheese'}): 0.5015873015873016, frozenset({'Pencil'}): 0.3619047619047619, frozenset({'Meat'}): 0.47619047619047616, frozenset({'Bread'}): 0.5047619047619047, frozenset({'Eggs'}): 0.4380952380952381, frozenset({'Wine'}): 0.4380952380952381, frozenset({'Milk'}): 0.5015873015873016, frozenset({'Bagel'}): 0.4253968253968254, frozenset({''}): 0.09523809523809523, frozenset({'Diaper', 'Cheese'}): 0.2, frozenset({'Pencil', 'Diaper'}): 0.17142857142857143, frozenset({'Meat', 'Diaper'}): 0.19365079365079366, frozenset({'Bread', 'Diaper'}): 0.23174603174603176, frozenset({'Eggs', 'Diaper'}): 0.1619047619047619, frozenset({'Wine', 'Diaper'}): 0.23492063492063492, frozenset({'Pencil', 'Cheese'}): 0.2, frozenset({'Meat', 'Cheese'}): 0.3238095238095238, frozenset({'Bread', 'Cheese'}): 0.23809523809523808, frozenset({'Eggs', 'Cheese'}): 0.2984126984126984, frozenset({'Wine', 'Cheese'}): 0.2698412698412698, frozenset({'Pencil', 'Meat'}): 0.17777777777777778, frozenset({'Pencil', 'Bread'}): 0.2, frozenset({'Pencil', 'Eggs'}): 0.16507936507936508, frozenset({'Pencil', 'Wine'}): 0.2, frozenset({'Meat', 'Bread'}): 0.20634920634920634, frozenset({'Eggs', 'Meat'}): 0.26666666666666666, frozenset({'Meat', 'Wine'}): 0.2507936507936508, frozenset({'Eggs', 'Bread'}): 0.1873015873015873, frozenset({'Wine', 'Bread'}): 0.24444444444444444, frozenset({'Eggs', 'Wine'}): 0.24126984126984127, frozenset({'Milk', 'Diaper'}): 0.15555555555555556, frozenset({'Milk', 'Cheese'}): 0.3047619047619048, frozenset({'Pencil', 'Milk'}): 0.17142857142857143, frozenset({'Meat', 'Milk'}): 0.24444444444444444, frozenset({'Bread', 'Milk'}): 0.27936507936507937, frozenset({'Wine', 'Milk'}): 0.21904761904761905, frozenset({'Eggs', 'Milk'}): 0.24444444444444444, frozenset({'Bagel', 'Diaper'}): 0.18412698412698414, frozenset({'Bagel', 'Pencil'}): 0.15873015873015872, frozenset({'Bagel', 'Bread'}): 0.27936507936507937, frozenset({'Bagel', 'Eggs'}): 0.1523809523809524, frozenset({'Bagel', 'Wine'}): 0.17142857142857143, frozenset({'Bagel', 'Milk'}): 0.2253968253968254, frozenset({'Bagel', 'Cheese'}): 0.19365079365079366, frozenset({'Bagel', 'Meat'}): 0.19047619047619047, frozenset({'Pencil', 'Diaper', 'Cheese'}): 0.08888888888888889, frozenset({'Meat', 'Diaper', 'Cheese'}): 0.11428571428571428, frozenset({'Bread', 'Diaper', 'Cheese'}): 0.1365079365079365, frozenset({'Eggs', 'Diaper', 'Cheese'}): 0.10158730158730159, frozenset({'Wine', 'Diaper', 'Cheese'}): 0.1365079365079365, frozenset({'Pencil', 'Meat', 'Diaper'}): 0.08253968253968254, frozenset({'Pencil', 'Bread', 'Diaper'}): 0.10476190476190476, frozenset({'Pencil', 'Eggs', 'Diaper'}): 0.08253968253968254, frozenset({'Pencil', 'Wine', 'Diaper'}): 0.10793650793650794, frozenset({'Meat', 'Bread', 'Diaper'}): 0.12063492063492064, frozenset({'Eggs', 'Meat', 'Diaper'}): 0.08571428571428572, frozenset({'Meat', 'Wine', 'Diaper'}): 0.12380952380952381, frozenset({'Eggs', 'Bread', 'Diaper'}): 0.08888888888888889, frozenset({'Wine', 'Bread', 'Diaper'}): 0.1492063492063492, frozenset({'Eggs', 'Wine', 'Diaper'}): 0.1111111111111111, frozenset({'Pencil', 'Meat', 'Cheese'}): 0.10476190476190476, frozenset({'Pencil', 'Bread', 'Cheese'}): 0.12380952380952381, frozenset({'Pencil', 'Eggs', 'Cheese'}): 0.10793650793650794, frozenset({'Pencil', 'Wine', 'Cheese'}): 0.12698412698412698, frozenset({'Meat', 'Bread', 'Cheese'}): 0.14285714285714285, frozenset({'Eggs', 'Meat', 'Cheese'}): 0.21587301587301588, frozenset({'Meat', 'Wine', 'Cheese'}): 0.16825396825396827, frozenset({'Eggs', 'Bread', 'Cheese'}): 0.11746031746031746, frozenset({'Wine', 'Bread', 'Cheese'}): 0.14285714285714285, frozenset({'Eggs', 'Wine', 'Cheese'}): 0.16507936507936508, frozenset({'Pencil', 'Meat', 'Bread'}): 0.1111111111111111, frozenset({'Pencil', 'Meat', 'Eggs'}): 0.07936507936507936, frozenset({'Pencil', 'Meat', 'Wine'}): 0.11428571428571428, frozenset({'Pencil', 'Eggs', 'Bread'}): 0.09841269841269841, frozenset({'Penci ...
#
#  Candidate 1 -itemset has  10 items
#
#   frozenset({'Diaper'}) :  0.41     frozenset({'Cheese'}) :  0.5     frozenset({'Pencil'}) :  0.36     frozenset({'Meat'}) :  0.48     frozenset({'Bread'}) :  0.5     frozenset({'Eggs'}) :  0.44     frozenset({'Wine'}) :  0.44     frozenset({'Milk'}) :  0.5     frozenset({'Bagel'}) :  0.43     frozenset({''}) :  0.1     frozenset({'Diaper'}) :  0.41     frozenset({'Cheese'}) :  0.5     frozenset({'Pencil'}) :  0.36     frozenset({'Meat'}) :  0.48     frozenset({'Bread'}) :  0.5     frozenset({'Eggs'}) :  0.44     frozenset({'Wine'}) :  0.44     frozenset({'Milk'}) :  0.5     frozenset({'Bagel'}) :  0.43
#
#  Eliminated Candidate 1 -itemset has  9 items
#
#   frozenset({'Diaper'}) :  0.41     frozenset({'Cheese'}) :  0.5     frozenset({'Pencil'}) :  0.36     frozenset({'Meat'}) :  0.48     frozenset({'Bread'}) :  0.5     frozenset({'Eggs'}) :  0.44     frozenset({'Wine'}) :  0.44     frozenset({'Milk'}) :  0.5     frozenset({'Bagel'}) :  0.43
#
#  Candidate 2 -itemset has  36 items
#
#   frozenset({'Diaper', 'Cheese'}) :  0.2     frozenset({'Pencil', 'Diaper'}) :  0.17     frozenset({'Meat', 'Diaper'}) :  0.19     frozenset({'Bread', 'Diaper'}) :  0.23     frozenset({'Eggs', 'Diaper'}) :  0.16     frozenset({'Wine', 'Diaper'}) :  0.23     frozenset({'Milk', 'Diaper'}) :  0.16     frozenset({'Bagel', 'Diaper'}) :  0.18     frozenset({'Pencil', 'Cheese'}) :  0.2     frozenset({'Meat', 'Cheese'}) :  0.32     frozenset({'Bread', 'Cheese'}) :  0.24     frozenset({'Eggs', 'Cheese'}) :  0.3     frozenset({'Wine', 'Cheese'}) :  0.27     frozenset({'Milk', 'Cheese'}) :  0.3     frozenset({'Bagel', 'Cheese'}) :  0.19     frozenset({'Pencil', 'Meat'}) :  0.18     frozenset({'Pencil', 'Bread'}) :  0.2     frozenset({'Pencil', 'Eggs'}) :  0.17     frozenset({'Pencil', 'Wine'}) :  0.2     frozenset({'Pencil', 'Milk'}) :  0.17     frozenset({'Bagel', 'Pencil'}) :  0.16     frozenset({'Meat', 'Bread'}) :  0.21     frozenset({'Eggs', 'Meat'}) :  0.27     frozenset({'Meat', 'Wine'}) :  0.25     frozenset({'Meat', 'Milk'}) :  0.24     frozenset({'Bagel', 'Meat'}) :  0.19     frozenset({'Eggs', 'Bread'}) :  0.19     frozenset({'Wine', 'Bread'}) :  0.24     frozenset({'Bread', 'Milk'}) :  0.28     frozenset({'Bagel', 'Bread'}) :  0.28     frozenset({'Eggs', 'Wine'}) :  0.24     frozenset({'Eggs', 'Milk'}) :  0.24     frozenset({'Bagel', 'Eggs'}) :  0.15     frozenset({'Wine', 'Milk'}) :  0.22     frozenset({'Bagel', 'Wine'}) :  0.17     frozenset({'Bagel', 'Milk'}) :  0.23     frozenset({'Diaper', 'Cheese'}) :  0.2     frozenset({'Pencil', 'Diaper'}) :  0.17     frozenset({'Meat', 'Diaper'}) :  0.19     frozenset({'Bread', 'Diaper'}) :  0.23     frozenset({'Eggs', 'Diaper'}) :  0.16     frozenset({'Wine', 'Diaper'}) :  0.23     frozenset({'Milk', 'Diaper'}) :  0.16     frozenset({'Bagel', 'Diaper'}) :  0.18     frozenset({'Pencil', 'Cheese'}) :  0.2     frozenset({'Meat', 'Cheese'}) :  0.32     frozenset({'Bread', 'Cheese'}) :  0.24     frozenset({'Eggs', 'Cheese'}) :  0.3     frozenset({'Wine', 'Cheese'}) :  0.27     frozenset({'Milk', 'Cheese'}) :  0.3     frozenset({'Bagel', 'Cheese'}) :  0.19     frozenset({'Pencil', 'Meat'}) :  0.18     frozenset({'Pencil', 'Bread'}) :  0.2     frozenset({'Pencil', 'Eggs'}) :  0.17     frozenset({'Pencil', 'Wine'}) :  0.2     frozenset({'Pencil', 'Milk'}) :  0.17     frozenset({'Bagel', 'Pencil'}) :  0.16     frozenset({'Meat', 'Bread'}) :  0.21     frozenset({'Eggs', 'Meat'}) :  0.27     frozenset({'Meat', 'Wine'}) :  0.25     frozenset({'Meat', 'Milk'}) :  0.24     frozenset({'Bagel', 'Meat'}) :  0.19     frozenset({'Eggs', 'Bread'}) :  0.19     frozenset({'Wine', 'Bread'}) :  0.24     frozenset({'Bread', 'Milk'}) :  0.28     frozenset({'Bagel', 'Bread'}) :  0.28     frozenset({'Eggs', 'Wine'}) :  0.24     frozenset({'Eggs', 'Milk'}) :  0.24     frozenset({'Bagel', 'Eggs'}) :  0.15     frozenset({'Wine', 'Milk'}) :  0.22     frozenset({'Bagel', 'Wine'}) :  0.17     frozenset({'Bagel', 'Milk'}) :  0.23
#
#  Eliminated Candidate 2 -itemset has  36 items
#
#   frozenset({'Diaper', 'Cheese'}) :  0.2     frozenset({'Pencil', 'Diaper'}) :  0.17     frozenset({'Meat', 'Diaper'}) :  0.19     frozenset({'Bread', 'Diaper'}) :  0.23     frozenset({'Eggs', 'Diaper'}) :  0.16     frozenset({'Wine', 'Diaper'}) :  0.23     frozenset({'Pencil', 'Cheese'}) :  0.2     frozenset({'Meat', 'Cheese'}) :  0.32     frozenset({'Bread', 'Cheese'}) :  0.24     frozenset({'Eggs', 'Cheese'}) :  0.3     frozenset({'Wine', 'Cheese'}) :  0.27     frozenset({'Pencil', 'Meat'}) :  0.18     frozenset({'Pencil', 'Bread'}) :  0.2     frozenset({'Pencil', 'Eggs'}) :  0.17     frozenset({'Pencil', 'Wine'}) :  0.2     frozenset({'Meat', 'Bread'}) :  0.21     frozenset({'Eggs', 'Meat'}) :  0.27     frozenset({'Meat', 'Wine'}) :  0.25     frozenset({'Eggs', 'Bread'}) :  0.19     frozenset({'Wine', 'Bread'}) :  0.24     frozenset({'Eggs', 'Wine'}) :  0.24     frozenset({'Milk', 'Diaper'}) :  0.16     frozenset({'Milk', 'Cheese'}) :  0.3     frozenset({'Pencil', 'Milk'}) :  0.17     frozenset({'Meat', 'Milk'}) :  0.24     frozenset({'Bread', 'Milk'}) :  0.28     frozenset({'Wine', 'Milk'}) :  0.22     frozenset({'Eggs', 'Milk'}) :  0.24     frozenset({'Bagel', 'Diaper'}) :  0.18     frozenset({'Bagel', 'Pencil'}) :  0.16     frozenset({'Bagel', 'Bread'}) :  0.28     frozenset({'Bagel', 'Eggs'}) :  0.15     frozenset({'Bagel', 'Wine'}) :  0.17     frozenset({'Bagel', 'Milk'}) :  0.23     frozenset({'Bagel', 'Cheese'}) :  0.19     frozenset({'Bagel', 'Meat'}) :  0.19
#
#  Candidate 3 -itemset has  84 items
#
#   frozenset({'Pencil', 'Diaper', 'Cheese'}) :  0.09     frozenset({'Meat', 'Diaper', 'Cheese'}) :  0.11     frozenset({'Bread', 'Diaper', 'Cheese'}) :  0.14     frozenset({'Eggs', 'Diaper', 'Cheese'}) :  0.1     frozenset({'Wine', 'Diaper', 'Cheese'}) :  0.14     frozenset({'Milk', 'Diaper', 'Cheese'}) :  0.1     frozenset({'Bagel', 'Diaper', 'Cheese'}) :  0.11     frozenset({'Pencil', 'Meat', 'Diaper'}) :  0.08     frozenset({'Pencil', 'Bread', 'Diaper'}) :  0.1     frozenset({'Pencil', 'Eggs', 'Diaper'}) :  0.08     frozenset({'Pencil', 'Wine', 'Diaper'}) :  0.11     frozenset({'Milk', 'Pencil', 'Diaper'}) :  0.07     frozenset({'Bagel', 'Pencil', 'Diaper'}) :  0.08     frozenset({'Meat', 'Bread', 'Diaper'}) :  0.12     frozenset({'Eggs', 'Meat', 'Diaper'}) :  0.09     frozenset({'Meat', 'Wine', 'Diaper'}) :  0.12     frozenset({'Milk', 'Meat', 'Diaper'}) :  0.06     frozenset({'Bagel', 'Meat', 'Diaper'}) :  0.1     frozenset({'Eggs', 'Bread', 'Diaper'}) :  0.09     frozenset({'Wine', 'Bread', 'Diaper'}) :  0.15     frozenset({'Milk', 'Bread', 'Diaper'}) :  0.11     frozenset({'Bagel', 'Bread', 'Diaper'}) :  0.12     frozenset({'Eggs', 'Wine', 'Diaper'}) :  0.11     frozenset({'Milk', 'Eggs', 'Diaper'}) :  0.07     frozenset({'Bagel', 'Eggs', 'Diaper'}) :  0.07     frozenset({'Milk', 'Wine', 'Diaper'}) :  0.09     frozenset({'Bagel', 'Wine', 'Diaper'}) :  0.1     frozenset({'Pencil', 'Meat', 'Cheese'}) :  0.1     frozenset({'Pencil', 'Bread', 'Cheese'}) :  0.12     frozenset({'Pencil', 'Eggs', 'Cheese'}) :  0.11     frozenset({'Pencil', 'Wine', 'Cheese'}) :  0.13     frozenset({'Pencil', 'Milk', 'Cheese'}) :  0.1     frozenset({'Bagel', 'Pencil', 'Cheese'}) :  0.09     frozenset({'Meat', 'Bread', 'Cheese'}) :  0.14     frozenset({'Eggs', 'Meat', 'Cheese'}) :  0.22     frozenset({'Meat', 'Wine', 'Cheese'}) :  0.17     frozenset({'Meat', 'Milk', 'Cheese'}) :  0.2     frozenset({'Bagel', 'Meat', 'Cheese'}) :  0.12     frozenset({'Eggs', 'Bread', 'Cheese'}) :  0.12     frozenset({'Wine', 'Bread', 'Cheese'}) :  0.14     frozenset({'Bread', 'Milk', 'Cheese'}) :  0.13     frozenset({'Bagel', 'Bread', 'Cheese'}) :  0.1     frozenset({'Eggs', 'Wine', 'Cheese'}) :  0.17     frozenset({'Eggs', 'Milk', 'Cheese'}) :  0.2     frozenset({'Bagel', 'Eggs', 'Cheese'}) :  0.09     frozenset({'Wine', 'Milk', 'Cheese'}) :  0.16     frozenset({'Bagel', 'Wine', 'Cheese'}) :  0.11     frozenset({'Pencil', 'Meat', 'Bread'}) :  0.11     frozenset({'Pencil', 'Meat', 'Eggs'}) :  0.08     frozenset({'Pencil', 'Meat', 'Wine'}) :  0.11     frozenset({'Pencil', 'Meat', 'Milk'}) :  0.08     frozenset({'Bagel', 'Pencil', 'Meat'}) :  0.09     frozenset({'Pencil', 'Eggs', 'Bread'}) :  0.1     frozenset({'Pencil', 'Wine', 'Bread'}) :  0.11     frozenset({'Pencil', 'Bread', 'Milk'}) :  0.11     frozenset({'Bagel', 'Pencil', 'Bread'}) :  0.09     frozenset({'Pencil', 'Wine', 'Eggs'}) :  0.12     frozenset({'Pencil', 'Eggs', 'Milk'}) :  0.09     frozenset({'Bagel', 'Pencil', 'Eggs'}) :  0.07     frozenset({'Pencil', 'Wine', 'Milk'}) :  0.1     frozenset({'Bagel', 'Pencil', 'Wine'}) :  0.08     frozenset({'Eggs', 'Meat', 'Bread'}) :  0.09     frozenset({'Wine', 'Meat', 'Bread'}) :  0.13     frozenset({'Meat', 'Bread', 'Milk'}) :  0.1     frozenset({'Bagel', 'Meat', 'Bread'}) :  0.11     frozenset({'Eggs', 'Meat', 'Wine'}) :  0.15     frozenset({'Eggs', 'Meat', 'Milk'}) :  0.18     frozenset({'Bagel', 'Eggs', 'Meat'}) :  0.09     frozenset({'Meat', 'Wine', 'Milk'}) :  0.13     frozenset({'Bagel', 'Meat', 'Wine'}) :  0.1     frozenset({'Eggs', 'Wine', 'Bread'}) :  0.12     frozenset({'Eggs', 'Bread', 'Milk'}) :  0.1     frozenset({'Bagel', 'Eggs', 'Bread'}) :  0.09     frozenset({'Wine', 'Bread', 'Milk'}) :  0.13     frozenset({'Bagel', 'Wine', 'Bread'}) :  0.1     frozenset({'Eggs', 'Wine', 'Milk'}) :  0.14     frozenset({'Bagel', 'Eggs', 'Wine'}) :  0.09     frozenset({'Milk', 'Bagel', 'Diaper'}) :  0.08     frozenset({'Bagel', 'Milk', 'Cheese'}) :  0.09     frozen ...
#
#  Eliminated Candidate 3 -itemset has  51 items
#
#   frozenset({'Meat', 'Diaper', 'Cheese'}) :  0.11     frozenset({'Bread', 'Diaper', 'Cheese'}) :  0.14     frozenset({'Eggs', 'Diaper', 'Cheese'}) :  0.1     frozenset({'Wine', 'Diaper', 'Cheese'}) :  0.14     frozenset({'Pencil', 'Bread', 'Diaper'}) :  0.1     frozenset({'Pencil', 'Wine', 'Diaper'}) :  0.11     frozenset({'Meat', 'Bread', 'Diaper'}) :  0.12     frozenset({'Meat', 'Wine', 'Diaper'}) :  0.12     frozenset({'Wine', 'Bread', 'Diaper'}) :  0.15     frozenset({'Eggs', 'Wine', 'Diaper'}) :  0.11     frozenset({'Pencil', 'Meat', 'Cheese'}) :  0.1     frozenset({'Pencil', 'Bread', 'Cheese'}) :  0.12     frozenset({'Pencil', 'Eggs', 'Cheese'}) :  0.11     frozenset({'Pencil', 'Wine', 'Cheese'}) :  0.13     frozenset({'Meat', 'Bread', 'Cheese'}) :  0.14     frozenset({'Eggs', 'Meat', 'Cheese'}) :  0.22     frozenset({'Meat', 'Wine', 'Cheese'}) :  0.17     frozenset({'Eggs', 'Bread', 'Cheese'}) :  0.12     frozenset({'Wine', 'Bread', 'Cheese'}) :  0.14     frozenset({'Eggs', 'Wine', 'Cheese'}) :  0.17     frozenset({'Pencil', 'Meat', 'Bread'}) :  0.11     frozenset({'Pencil', 'Meat', 'Wine'}) :  0.11     frozenset({'Pencil', 'Wine', 'Bread'}) :  0.11     frozenset({'Pencil', 'Wine', 'Eggs'}) :  0.12     frozenset({'Wine', 'Meat', 'Bread'}) :  0.13     frozenset({'Eggs', 'Meat', 'Wine'}) :  0.15     frozenset({'Eggs', 'Wine', 'Bread'}) :  0.12     frozenset({'Milk', 'Bread', 'Diaper'}) :  0.11     frozenset({'Pencil', 'Milk', 'Cheese'}) :  0.1     frozenset({'Meat', 'Milk', 'Cheese'}) :  0.2     frozenset({'Bread', 'Milk', 'Cheese'}) :  0.13     frozenset({'Wine', 'Milk', 'Cheese'}) :  0.16     frozenset({'Pencil', 'Bread', 'Milk'}) :  0.11     frozenset({'Meat', 'Bread', 'Milk'}) :  0.1     frozenset({'Meat', 'Wine', 'Milk'}) :  0.13     frozenset({'Wine', 'Bread', 'Milk'}) :  0.13     frozenset({'Eggs', 'Milk', 'Cheese'}) :  0.2     frozenset({'Eggs', 'Meat', 'Milk'}) :  0.18     frozenset({'Eggs', 'Wine', 'Milk'}) :  0.14     frozenset({'Bagel', 'Bread', 'Diaper'}) :  0.12     frozenset({'Bagel', 'Wine', 'Diaper'}) :  0.1     frozenset({'Eggs', 'Bread', 'Milk'}) :  0.1     frozenset({'Bagel', 'Wine', 'Bread'}) :  0.1     frozenset({'Bagel', 'Bread', 'Milk'}) :  0.17     frozenset({'Bagel', 'Diaper', 'Cheese'}) :  0.11     frozenset({'Bagel', 'Meat', 'Diaper'}) :  0.1     frozenset({'Bagel', 'Meat', 'Cheese'}) :  0.12     frozenset({'Bagel', 'Wine', 'Cheese'}) :  0.11     frozenset({'Bagel', 'Meat', 'Wine'}) :  0.1     frozenset({'Bagel', 'Meat', 'Bread'}) :  0.11     frozenset({'Bagel', 'Bread', 'Cheese'}) :  0.1
#
#  Candidate 4 -itemset has  94 items
#
#   frozenset({'Meat', 'Bread', 'Diaper', 'Cheese'}) :  0.08     frozenset({'Meat', 'Diaper', 'Cheese', 'Eggs'}) :  0.06     frozenset({'Meat', 'Diaper', 'Cheese', 'Wine'}) :  0.07     frozenset({'Meat', 'Diaper', 'Cheese', 'Pencil'}) :  0.04     frozenset({'Meat', 'Diaper', 'Cheese', 'Milk'}) :  0.04     frozenset({'Bagel', 'Meat', 'Diaper', 'Cheese'}) :  0.07     frozenset({'Bread', 'Diaper', 'Cheese', 'Eggs'}) :  0.06     frozenset({'Bread', 'Diaper', 'Cheese', 'Wine'}) :  0.09     frozenset({'Bread', 'Diaper', 'Cheese', 'Pencil'}) :  0.06     frozenset({'Bread', 'Diaper', 'Cheese', 'Milk'}) :  0.07     frozenset({'Bagel', 'Bread', 'Diaper', 'Cheese'}) :  0.07     frozenset({'Diaper', 'Cheese', 'Eggs', 'Wine'}) :  0.07     frozenset({'Diaper', 'Cheese', 'Pencil', 'Eggs'}) :  0.05     frozenset({'Diaper', 'Cheese', 'Eggs', 'Milk'}) :  0.05     frozenset({'Bagel', 'Diaper', 'Cheese', 'Eggs'}) :  0.05     frozenset({'Diaper', 'Cheese', 'Pencil', 'Wine'}) :  0.06     frozenset({'Diaper', 'Cheese', 'Wine', 'Milk'}) :  0.07     frozenset({'Bagel', 'Diaper', 'Cheese', 'Wine'}) :  0.07     frozenset({'Bread', 'Diaper', 'Pencil', 'Wine'}) :  0.06     frozenset({'Meat', 'Bread', 'Diaper', 'Pencil'}) :  0.06     frozenset({'Bread', 'Diaper', 'Pencil', 'Milk'}) :  0.05     frozenset({'Bagel', 'Bread', 'Diaper', 'Pencil'}) :  0.05     frozenset({'Meat', 'Diaper', 'Pencil', 'Wine'}) :  0.06     frozenset({'Diaper', 'Pencil', 'Wine', 'Eggs'}) :  0.06     frozenset({'Bagel', 'Diaper', 'Pencil', 'Wine'}) :  0.04     frozenset({'Meat', 'Bread', 'Diaper', 'Wine'}) :  0.08     frozenset({'Meat', 'Bread', 'Diaper', 'Milk'}) :  0.05     frozenset({'Bagel', 'Meat', 'Bread', 'Diaper'}) :  0.07     frozenset({'Meat', 'Diaper', 'Eggs', 'Wine'}) :  0.06     frozenset({'Meat', 'Diaper', 'Wine', 'Milk'}) :  0.04     frozenset({'Bagel', 'Meat', 'Diaper', 'Wine'}) :  0.05     frozenset({'Bread', 'Diaper', 'Eggs', 'Wine'}) :  0.06     frozenset({'Bread', 'Diaper', 'Wine', 'Milk'}) :  0.07     frozenset({'Bagel', 'Bread', 'Diaper', 'Wine'}) :  0.06     frozenset({'Diaper', 'Eggs', 'Wine', 'Milk'}) :  0.04     frozenset({'Bagel', 'Diaper', 'Eggs', 'Wine'}) :  0.05     frozenset({'Meat', 'Bread', 'Cheese', 'Pencil'}) :  0.08     frozenset({'Meat', 'Cheese', 'Pencil', 'Eggs'}) :  0.05     frozenset({'Meat', 'Cheese', 'Pencil', 'Wine'}) :  0.07     frozenset({'Meat', 'Cheese', 'Pencil', 'Milk'}) :  0.05     frozenset({'Bagel', 'Meat', 'Cheese', 'Pencil'}) :  0.04     frozenset({'Bread', 'Cheese', 'Pencil', 'Eggs'}) :  0.07     frozenset({'Bread', 'Cheese', 'Pencil', 'Wine'}) :  0.07     frozenset({'Bread', 'Cheese', 'Pencil', 'Milk'}) :  0.06     frozenset({'Bagel', 'Bread', 'Cheese', 'Pencil'}) :  0.05     frozenset({'Cheese', 'Pencil', 'Wine', 'Eggs'}) :  0.09     frozenset({'Cheese', 'Pencil', 'Eggs', 'Milk'}) :  0.05     frozenset({'Cheese', 'Pencil', 'Wine', 'Milk'}) :  0.06     frozenset({'Bagel', 'Cheese', 'Pencil', 'Wine'}) :  0.05     frozenset({'Meat', 'Bread', 'Cheese', 'Eggs'}) :  0.06     frozenset({'Meat', 'Bread', 'Cheese', 'Wine'}) :  0.09     frozenset({'Meat', 'Bread', 'Cheese', 'Milk'}) :  0.08     frozenset({'Bagel', 'Meat', 'Bread', 'Cheese'}) :  0.07     frozenset({'Meat', 'Cheese', 'Eggs', 'Wine'}) :  0.11     frozenset({'Meat', 'Cheese', 'Eggs', 'Milk'}) :  0.15     frozenset({'Bagel', 'Meat', 'Cheese', 'Eggs'}) :  0.06     frozenset({'Meat', 'Cheese', 'Wine', 'Milk'}) :  0.1     frozenset({'Bagel', 'Meat', 'Cheese', 'Wine'}) :  0.06     frozenset({'Bread', 'Cheese', 'Eggs', 'Wine'}) :  0.07     frozenset({'Bread', 'Cheese', 'Eggs', 'Milk'}) :  0.07     frozenset({'Bagel', 'Bread', 'Cheese', 'Eggs'}) :  0.04     frozenset({'Bread', 'Cheese', 'Wine', 'Milk'}) :  0.09     frozenset({'Bagel', 'Bread', 'Cheese', 'Wine'}) :  0.06     frozenset({'Cheese', 'Eggs', 'Wine', 'Milk'}) :  0.1     frozenset({'Bagel', 'Cheese', 'Eggs', 'Wine'}) :  0.06     frozenset({'Meat', 'Bread', 'Pencil', 'Wine'}) :  0.07     frozenset({'Meat', 'Bread', 'Pencil',  ...
#
#  Eliminated Candidate 4 -itemset has  4 items
#
#   frozenset({'Meat', 'Cheese', 'Eggs', 'Wine'}) :  0.11     frozenset({'Meat', 'Cheese', 'Wine', 'Milk'}) :  0.1     frozenset({'Meat', 'Cheese', 'Eggs', 'Milk'}) :  0.15     frozenset({'Cheese', 'Eggs', 'Wine', 'Milk'}) :  0.1
#
#  Candidate 5 -itemset has  1 items
#
#   frozenset({'Cheese', 'Meat', 'Eggs', 'Wine', 'Milk'}) :  0.07
#
#  Eliminated Candidate 5 -itemset has  0 items
#
#
#
#  Candidate 6 -itemset has  0 items
#
#
#
#  Eliminated Candidate 6 -itemset has  0 items

# %% [markdown]
# Some output - I think it is correct, but if you find problems, let me know
#
# ```
# Transaction file: /content/drive/MyDrive/CS Classes/CSC_373_Data_Mining/CSC_373_Student_Files/Data/Table_5_1.txt
#
# min_sup 2
#
# Number of transactions: 5
#
# Candidate 1-itemset has 6 items.
# {'Bread': 4, 'Milk': 4, 'Beer': 3, 'Diapers': 4, 'Eggs': 1, 'Cola': 2}
#
# Pruned 1-itemset is the same as the eliminated 1-itemset.
#
# Eliminated 1-itemset has 5 items.
# {'Bread': 4, 'Milk': 4, 'Beer': 3, 'Diapers': 4, 'Cola': 2}
#
# Candidate 2-itemset has 10 items.
# {'Bread,Milk': 0, 'Beer,Bread': 0, 'Bread,Diapers': 0, 'Bread,Cola': 0, 'Beer,Milk': 0, 'Diapers,Milk': 0, 'Cola,Milk': 0, 'Beer,Diapers': 0, 'Beer,Cola': 0, 'Cola,Diapers': 0}
#
# Pruned 2-itemset has 10 items.
# {'Bread,Milk': 0, 'Beer,Bread': 0, 'Bread,Diapers': 0, 'Bread,Cola': 0, 'Beer,Milk': 0, 'Diapers,Milk': 0, 'Cola,Milk': 0, 'Beer,Diapers': 0, 'Beer,Cola': 0, 'Cola,Diapers': 0}
#
# Eliminated 2-itemset has 8 items.
# {'Bread,Milk': 3, 'Beer,Bread': 2, 'Bread,Diapers': 3, 'Beer,Milk': 2, 'Diapers,Milk': 3, 'Cola,Milk': 2, 'Beer,Diapers': 3, 'Cola,Diapers': 2}
#
# Candidate 3-itemset has 10 items.
# {'Beer,Bread,Milk': 0, 'Bread,Diapers,Milk': 0, 'Bread,Cola,Milk': 0, 'Beer,Bread,Diapers': 0, 'Bread,Cola,Diapers': 0, 'Beer,Diapers,Milk': 0, 'Cola,Diapers,Milk': 0, 'Beer,Cola,Milk': 0, 'Beer,Cola,Diapers': 0, 'Beer,Bread,Cola': 0}
#
# Pruned 3-itemset has 5 items.
# {'Beer,Bread,Milk': 0, 'Bread,Diapers,Milk': 0, 'Beer,Bread,Diapers': 0, 'Beer,Diapers,Milk': 0, 'Cola,Diapers,Milk': 0}
#
# Eliminated 3-itemset has 4 items.
# {'Bread,Diapers,Milk': 2, 'Beer,Bread,Diapers': 2, 'Beer,Diapers,Milk': 2, 'Cola,Diapers,Milk': 2}
#
# Candidate 4-itemset has 4 items.
# {'Beer,Bread,Diapers,Milk': 0, 'Bread,Cola,Diapers,Milk': 0, 'Beer,Cola,Diapers,Milk': 0, 'Beer,Bread,Cola,Diapers': 0}
#
# Pruned 4-itemset has 0 items.
# {}
#
# Eliminated 4-itemset has 0 items.
# {}
# END
#
# ```
